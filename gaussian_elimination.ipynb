# %% [markdown]
# # Comparación: Eliminación Gaussiana - Gauss-Jordan

# %%
# %load_ext autoreload

# %% [markdown]
# ## Detalles de la ejecución:
#
# - Se generaron 5 matrices aumentadas aleatorias de tamaños
#   - 20x21
#   - 40x41
#   - 60x61
#   - 80x81
#   - 100x101
# - Los valores fueron enteros aleatorios entre -10 y 10.
# - A cada matriz se le aplicaron ambos métodos (`eliminacion_gaussiana` y `gauss_jordan`).
# - Se registraron dos métricas por método:
#   - Tiempo de ejecución
#   - Número total de operaciones aritméticas (sumas, restas, multiplicaciones y divisiones).
#
# ## Visualización:
#
# Se generó una gráfica comparativa en el plano cartesiano (tiempo vs operaciones) para visualizar el rendimiento de cada método.

# %%
from src import eliminacion_gaussiana, gauss_jordan, graficar_comparacion
import numpy as np

np.random.seed(42)
for n in [20, 40, 60, 80, 100]:
    Ab = np.random.randint(-10, 11, size=(n, n + 1)).astype(float)
    eliminacion_gaussiana(Ab.copy())
    gauss_jordan(Ab.copy())

graficar_comparacion()
# Out:
# [06-25 12:03:14][INFO] 2025-06-25 12:03:14.561061
# [06-25 12:03:14][INFO] [GAUSSIANA] Multiplicaciones: 3040, Divisiones: 210, Sumas: 190, Restas: 2869
# [06-25 12:03:14][INFO] [GAUSSIANA] Tiempo de ejecución: 0.000689 segundos
# [06-25 12:03:14][INFO] [GAUSS-JORDAN] Multiplicaciones: 4370, Divisiones: 400, Sumas: 0, Restas: 4370
# [06-25 12:03:14][INFO] [GAUSS-JORDAN] Tiempo de ejecución: 0.001511 segundos
# [06-25 12:03:14][INFO] [GAUSSIANA] Multiplicaciones: 22880, Divisiones: 820, Sumas: 780, Restas: 22139
# [06-25 12:03:14][INFO] [GAUSSIANA] Tiempo de ejecución: 0.004643 segundos
# [06-25 12:03:14][INFO] [GAUSS-JORDAN] Multiplicaciones: 33540, Divisiones: 1600, Sumas: 0, Restas: 33540
# [06-25 12:03:14][INFO] [GAUSS-JORDAN] Tiempo de ejecución: 0.006607 segundos
# [06-25 12:03:14][INFO] [GAUSSIANA] Multiplicaciones: 75520, Divisiones: 1830, Sumas: 1770, Restas: 73809
# [06-25 12:03:14][INFO] [GAUSSIANA] Tiempo de ejecución: 0.007860 segundos
# ...
